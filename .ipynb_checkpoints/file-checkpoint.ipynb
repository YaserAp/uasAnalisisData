# %%
#Bagaimana tren peminjaman sepeda berubah dari tahun 2011 ke tahun 2012? Apakah terdapat peningkatan atau penurunan yang signifikan?-10122340-MuhammadYaserAp

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv('hour.csv')


data['dteday'] = pd.to_datetime(data['dteday'])


data_2011 = data[data['yr'] == 0]
data_2012 = data[data['yr'] == 1]


peminjaman_2011 = data_2011.groupby(data_2011['dteday'].dt.month)['cnt'].sum()
peminjaman_2012 = data_2012.groupby(data_2012['dteday'].dt.month)['cnt'].sum()


plt.figure(figsize=(10, 6))
sns.lineplot(data=peminjaman_2011, label='2011', marker='o')
sns.lineplot(data=peminjaman_2012, label='2012', marker='o')
plt.title('Tren Peminjaman Sepeda (2011 vs 2012)')
plt.xlabel('Bulan')
plt.ylabel('Total Peminjaman Sepeda')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.show()

# %% [markdown]
# di atas ini d tunjukan perubahan tren peminjaman dimana tren yang d tunjukan d atas mengalami peningkatan yang signifikan sebagaimana d tunjukan tabel grafik d atas.

# %%
Nama: Muhammad Yaser Almatin Paris
NIM: 10122340
Kelas: IF-9

Note:
Sebelumnya mohon maaf pak saya tidak kebagian kelompok jadi saya membuat kelompok sendiri, terimakasih.
